# %% [markdown]
# El conjunto de datos del archivo Hotel.csv contiene información de reserva para un hotel urbano y un hotel resort, e incluye información como cuándo se realizó la reserva, duración de la estadía, la cantidad de adultos, niños y / o bebés, y la cantidad de espacios de estacionamiento disponibles, entre otras cosas. Toda la información de identificación personal se ha eliminado de los datos. Ambos hoteles están ubicados en Portugal. La columna “is_canceled” (1 es sí, 0 es no) para saber si fue o no cancelada

# %%
import json 
import pandas as pd
import calendar
from calendar import monthrange
import pycountry

# %%
df = pd.read_json("data.json")
df.head()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year arrival_date_month
# 0  City Hotel            1        615               2017              March  \
# 1  City Hotel            1        615               2017              March
# 2  City Hotel            1        615               2017              March
# 3  City Hotel            1        615               2017              March
# 4  City Hotel            1        615               2017              March
#
#    arrival_date_week_number  arrival_date_day_of_month
# 0                        11                         16  \
# 1                        11                         16
# 2                        11                         16
# 3                        11                         16
# 4                        11                         16
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ... deposit_type
# 0                        0                     2       2  ...   Non Refund  \
# 1                        0                     2       2  ...   Non Refund
# 2                        0                     2       2  ...   Non Refund
# 3                        0                     2       2  ...   Non Refund
# 4                        0                     2       2  ...   Non Refund
#
#    agent company days_in_waiting_list customer_type   adr
# 0      1    NULL                    0     Transient  62.0  \
# 1      1    NULL                    0     Transient  62.0
# 2      1    NULL                    0     Transient  62.0
# 3      1    NULL                    0     Transient  62.0
# 4      1    NULL                    0     Transient  62.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status
# 0                            0                          0            Canceled  \
# 1                            0                          0            Canceled
# 2                            0                          0            Canceled
# 3                            0                          0            Canceled
# 4                            0                          0            Canceled
#
#   reservation_status_date
# 0              21/10/2015
# 1              21/10/2015
# 2              21/10/2015
# 3              21/10/2015
# 4              21/10/2015
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# Limpieza de datos
#
# Para realizar la limpieza de datos se eliminan los valores duplicados en caso de existir, así como posibles columnas y filas con valores vacíos. Por otra parte, en el caso del adr se toman en cuenta solo aquellos valores mayores o iguales a cero, asumiento que no se tiene la opción de que el hotel retribuya económicamente al cliente por su reservación. Debido a que se desconoce el contexto del hotel no se eliminan valores muy altos, pues podría ser una suite especial. En caso de que se obtenga más información acerca del hotel, se podrá delimitar un máximo para evitar tomar en cuenta posibles valores atípicos que perjudiquen los resultados.

# %%
df = df.drop_duplicates()
df = df.dropna()
df = df.dropna(axis=1)
df = df[(df['adr'] >= 0)]
df.shape
# Out:
# (87395, 32)

# %% [markdown]
# A través de la limpieza delimitamos que se trabajará con 87396 reservaciones.

# %% [markdown]
# ¿De dónde vienen los huéspedes?

# %%
procedencia =  df['country'].value_counts()
print("Los huespedes provienen de los siguientes países: ", procedencia)
# Out:
# Los huespedes provienen de los siguientes países:  country
# PRT    27453
# GBR    10432
# FRA     8837
# ESP     7252
# DEU     5387
#        ...
# GLP        1
# PYF        1
# MDG        1
# GUY        1
# VGB        1
# Name: count, Length: 178, dtype: int64

# %% [markdown]
# ¿Cuánto pagan los huéspedes por una habitación por noche en promedio?

# %%
promedio_por_noche = round(df['adr'].mean(),2)
print("El pago promedio por noche es: $", promedio_por_noche)
# Out:
# El pago promedio por noche es: $ 106.34

# %% [markdown]
# En ocasiones, el promedio puede verse afectado por valores poco comunes, por lo cual, una forma más confiable de definir cuánto pagan los huespedes de forma general por noche sería utilizando la mediana o la moda, pues, la primera se encuentra justo en medio de los valores totales y la segunda nos presenta los más frecuentes. En este caso se utiliza la mediana como segundo ejemplo para tener un mayor contexto de la cantidad de dinero que pagan los clientes por noche, disminuyendo el sesgo generado por una varianza alta.

# %%
mediana_por_noche = round(df['adr'].median(),2)
print("La mediana del pago por noche es: $", mediana_por_noche)
# Out:
# La mediana del pago por noche es: $ 98.1

# %% [markdown]
# ¿Cómo varía el precio por noche durante el año?

# %%
round(df['adr'].describe(),2)
# Out:
# count    87395.00
# mean       106.34
# std         55.01
# min          0.00
# 25%         72.00
# 50%         98.10
# 75%        134.00
# max       5400.00
# Name: adr, dtype: float64

# %% [markdown]
# De forma general podemos observar que la desviación estandar del precio es de $55.01. Asimismo el 25% de los precios por noche se encuentran en el rango de $72.00 o menos. El 50% está en el rango de $98.10 o menos. Mientras que el 25% más alto está por encima de los $134.00. Asimismo, se observa que el máximo pagado fue de $5400.00,mientas que el mínimo es de $0.00 debido a que durante el proceso de limpieza de datos, los valores negativos no se tomaron en cuenta.

# %% [markdown]
# ¿Cuáles son los meses más ocupados?

# %%
ocupacion_meses = df['arrival_date_month'].value_counts()
print("Los meses más ocupados son:", ocupacion_meses[0:3])
# Out:
# Los meses más ocupados son: arrival_date_month
# August    11257
# July      10057
# May        8355
# Name: count, dtype: int64

# %%
ocupacion_meses
# Out:
# arrival_date_month
# August       11257
# July         10057
# May           8355
# April         7908
# June          7765
# March         7512
# October       6934
# September     6690
# February      6098
# December      5131
# November      4995
# January       4693
# Name: count, dtype: int64

# %% [markdown]
# ¿Cuánto tiempo se queda la gente en los hoteles (noches)?

# %%
df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
avr_total_nights = round(df['total_nights'].mean())

print("En promedio la gente se queda por", avr_total_nights, "noches")
# Out:
# En promedio la gente se queda por 4 noches

# %% [markdown]
# Reservas por segmento de mercado

# %%
reservas_segmento = df['market_segment'].value_counts()
print(reservas_segmento)
# Out:
# market_segment
# Online TA        51618
# Offline TA/TO    13889
# Direct           11804
# Groups            4941
# Corporate         4212
# Complementary      702
# Aviation           227
# Undefined            2
# Name: count, dtype: int64

# %% [markdown]
# Los segmentos que más realizaron reservas fue el de Online TA, seguido por Offline TA/TO.

# %% [markdown]
# ¿Cuántas reservas se cancelaron?

# %%
cancelaciones = df['is_canceled'].value_counts()
print("Se cancelaron", cancelaciones[1], "reservas")
# Out:
# Se cancelaron 24025 reservas

# %% [markdown]
# ¿Qué mes tiene el mayor número de cancelaciones?

# %%
df.filter(items = ['arrival_date_month','is_canceled']).value_counts()[12:]
# Out:
# arrival_date_month  is_canceled
# August              1              3623
# July                1              3198
# May                 1              2442
# April               1              2409
# June                1              2354
# March               1              1830
# October             1              1642
# September           1              1642
# February            1              1415
# December            1              1378
# November            1              1054
# January             1              1038
# Name: count, dtype: int64

# %% [markdown]
# El mes con mayor número de cancelaciones es Agosto, con 3623 cancelaciones.

# %% [markdown]
# Hacer tabla de correlación para las variables

# %%
numeric_type = df.drop(['is_canceled'], axis=1).select_dtypes(include='number')
numeric_type.corr()
# Out:
#                                 lead_time  arrival_date_year
# lead_time                        1.000000           0.139120  \
# arrival_date_year                0.139120           1.000000
# arrival_date_week_number         0.101171          -0.514220
# arrival_date_day_of_month        0.009885          -0.010007
# stays_in_weekend_nights          0.235115           0.005106
# stays_in_week_nights             0.310112           0.003624
# adults                           0.140491           0.038616
# babies                          -0.003612          -0.023333
# is_repeated_guest               -0.147101           0.024281
# previous_cancellations           0.005376          -0.054211
# previous_bookings_not_canceled  -0.078949           0.027242
# booking_changes                  0.076995           0.008573
# days_in_waiting_list             0.132154          -0.027938
# adr                              0.023596           0.176121
# required_car_parking_spaces     -0.086537          -0.039803
# total_of_special_requests        0.034253           0.064280
# total_nights                     0.318249           0.004599
#
#                                 arrival_date_week_number
# lead_time                                       0.101171  \
# arrival_date_year                              -0.514220
# arrival_date_week_number                        1.000000
# arrival_date_day_of_month                       0.093578
# stays_in_weekend_nights                         0.026910
# stays_in_week_nights                            0.027825
# adults                                          0.024365
# babies                                          0.014259
# is_repeated_guest                              -0.036795
# previous_cancellations                          0.007197
# previous_bookings_not_canceled                 -0.020805
# booking_changes                                 0.011936
# days_in_waiting_list                            0.013842
# adr                                             0.098254
# required_car_parking_spaces                     0.008942
# total_of_special_requests                       0.046588
# total_nights                                    0.030726
#
#                                 arrival_date_day_of_month
# lead_time                                        0.009885  \
# arrival_date_year                               -0.010007
# arrival_date_week_number                         0.093578
# arrival_date_day_of_month                        1.000000
# stays_in_weekend_nights                         -0.017763
# stays_in_week_nights                            -0.028168
# adults                                          -0.001122
# babies                                          -0.000395
# is_repeated_guest                               -0.004109
# previous_cancellations                          -0.008540
# previous_bookings_not_canceled                   0.000167
# booking_changes                                  0.006340
# days_in_waiting_list                             0.006587
# adr                                              0.022563
# required_car_parking_spaces                      0.009163
# total_of_special_requests                       -0.001662
# total_nights                                    -0.027565
#
#                                 stays_in_weekend_nights  stays_in_week_nights
# lead_time                                      0.235115              0.310112  \
# arrival_date_year                              0.005106              0.003624
# arrival_date_week_number                       0.026910              0.027825
# arrival_date_day_of_month                     -0.017763             -0.028168
# stays_in_weekend_nights                        1.000000              0.555533
# stays_in_week_nights                           0.555533              1.000000
# adults                                         0.088282              0.095575
# babies                                         0.013671              0.016011
# is_repeated_guest                             -0.107133             -0.113654
# previous_cancellations                        -0.020634             -0.018780
# previous_bookings_not_canceled                -0.056691             -0.058524
# booking_changes                                0.050241              0.085003
# days_in_waiting_list                          -0.031679              0.001906
# adr                                            0.039043              0.053339
# required_car_parking_spaces                   -0.042912             -0.044298
# total_of_special_requests                      0.032426              0.037839
# total_nights                                   0.786247              0.950577
#
#                                   adults    babies  is_repeated_guest
# lead_time                       0.140491 -0.003612          -0.147101  \
# arrival_date_year               0.038616 -0.023333           0.024281
# arrival_date_week_number        0.024365  0.014259          -0.036795
# arrival_date_day_of_month      -0.001122 -0.000395          -0.004109
# stays_in_weekend_nights         0.088282  0.013671          -0.107133
# stays_in_week_nights            0.095575  0.016011          -0.113654
# adults                          1.000000  0.016640          -0.171749
# babies                          0.016640  1.000000          -0.012974
# is_repeated_guest              -0.171749 -0.012974           1.000000
# previous_cancellations         -0.042097 -0.005395           0.206408
# previous_bookings_not_canceled -0.120917 -0.009191           0.441461
# booking_changes                -0.048068  0.081040           0.005913
# days_in_waiting_list           -0.015739 -0.006840          -0.012813
# adr                             0.249010  0.023444          -0.152949
# required_car_parking_spaces     0.007803  0.030884           0.072046
# total_of_special_requests       0.112775  0.094820          -0.001273
# total_nights                    0.103990  0.017003          -0.124465
#
#                                 previous_cancellations
# lead_time                                     0.005376  \
# arrival_date_year                            -0.054211
# arrival_date_week_number                      0.007197
# arrival_date_day_of_month                    -0.008540
# stays_in_weekend_nights                      -0.020634
# stays_in_week_nights                         -0.018780
# adults                                       -0.042097
# babies                                       -0.005395
# is_repeated_guest                             0.206408
# previous_cancellations                        1.000000
# previous_bookings_not_canceled                0.392068
# booking_changes                              -0.010267
# days_in_waiting_list                          0.003682
# adr                                          -0.050270
# required_car_parking_spaces                  -0.003399
# total_of_special_requests                     0.001870
# total_nights                                 -0.021661
#
#                                 previous_bookings_not_canceled
# lead_time                                            -0.078949  \
# arrival_date_year                                     0.027242
# arrival_date_week_number                             -0.020805
# arrival_date_day_of_month                             0.000167
# stays_in_weekend_nights                              -0.056691
# stays_in_week_nights                                 -0.058524
# adults                                               -0.120917
# babies                                               -0.009191
# is_repeated_guest                                     0.441461
# previous_cancellations                                0.392068
# previous_bookings_not_canceled                        1.000000
# booking_changes                                       0.005392
# days_in_waiting_list                                 -0.006303
# adr                                                  -0.085699
# required_car_parking_spaces                           0.040876
# total_of_special_requests                             0.027123
# total_nights                                         -0.064660
#
#                                 booking_changes  days_in_waiting_list
# lead_time                              0.076995              0.132154  \
# arrival_date_year                      0.008573             -0.027938
# arrival_date_week_number               0.011936              0.013842
# arrival_date_day_of_month              0.006340              0.006587
# stays_in_weekend_nights                0.050241             -0.031679
# stays_in_week_nights                   0.085003              0.001906
# adults                                -0.048068             -0.015739
# babies                                 0.081040             -0.006840
# is_repeated_guest                      0.005913             -0.012813
# previous_cancellations                -0.010267              0.003682
# previous_bookings_not_canceled         0.005392             -0.006303
# booking_changes                        1.000000              0.024207
# days_in_waiting_list                   0.024207              1.000000
# adr                                    0.002608             -0.033004
# required_car_parking_spaces            0.048727             -0.016068
# total_of_special_requests              0.016138             -0.049545
# total_nights                           0.081930             -0.010413
#
#                                      adr  required_car_parking_spaces
# lead_time                       0.023596                    -0.086537  \
# arrival_date_year               0.176121                    -0.039803
# arrival_date_week_number        0.098254                     0.008942
# arrival_date_day_of_month       0.022563                     0.009163
# stays_in_weekend_nights         0.039043                    -0.042912
# stays_in_week_nights            0.053339                    -0.044298
# adults                          0.249010                     0.007803
# babies                          0.023444                     0.030884
# is_repeated_guest              -0.152949                     0.072046
# previous_cancellations         -0.050270                    -0.003399
# previous_bookings_not_canceled -0.085699                     0.040876
# booking_changes                 0.002608                     0.048727
# days_in_waiting_list           -0.033004                    -0.016068
# adr                             1.000000                     0.039113
# required_car_parking_spaces     0.039113                     1.000000
# total_of_special_requests       0.137815                     0.048452
# total_nights                    0.054217                    -0.048943
#
#                                 total_of_special_requests  total_nights
# lead_time                                        0.034253      0.318249
# arrival_date_year                                0.064280      0.004599
# arrival_date_week_number                         0.046588      0.030726
# arrival_date_day_of_month                       -0.001662     -0.027565
# stays_in_weekend_nights                          0.032426      0.786247
# stays_in_week_nights                             0.037839      0.950577
# adults                                           0.112775      0.103990
# babies                                           0.094820      0.017003
# is_repeated_guest                               -0.001273     -0.124465
# previous_cancellations                           0.001870     -0.021661
# previous_bookings_not_canceled                   0.027123     -0.064660
# booking_changes                                  0.016138      0.081930
# days_in_waiting_list                            -0.049545     -0.010413
# adr                                              0.137815      0.054217
# required_car_parking_spaces                      0.048452     -0.048943
# total_of_special_requests                        1.000000      0.040228
# total_nights                                     0.040228      1.000000
